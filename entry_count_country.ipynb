# %%
import pandas as pd
import numpy
import os

file = pd.read_csv("/Users/ansonice/Desktop/rouge_intern/export_All-Companies-modified2--_2022-04-11_13-27-37.csv")

# %%
file
# Out:
#                 company email     Company Name  \
# 0      info@radpowerbikes.com  Rad Power Bikes
# 1        info@voltatrucks.com     Volta Trucks
# 2             info@fuergy.com           Fuergy
# 3                         NaN        Facedrive
# 4                         NaN     Power Ledger
# ...                       ...              ...
# 18302                     NaN   People Pattern
# 18303                     NaN           ncyclo
# 18304                     NaN        Micronote
# 18305                     NaN         ParAccel
# 18306                     NaN     NowledgeData
#
#                                          crunchbase link  \
# 0      https://www.crunchbase.com/organization/rad-po...
# 1      https://www.crunchbase.com/organization/volta-...
# 2         https://www.crunchbase.com/organization/fuergy
# 3      https://www.crunchbase.com/organization/facedrive
# 4      https://www.crunchbase.com/organization/power-...
# ...

# %%
country_count = file["HQ"].value_counts()

# %%
cc = country_count.to_frame()

# %%
cc.describe
# Out:
# <bound method NDFrame.describe of                                                     tech category
# Data Analytics                                                415
# SaaS                                                          405
# IT/Software/Platform                                          202
# Software                                                      188
# Internet Software & Services                                  179
# ...                                                           ...
# Insurance, Cars, Curated Web                                    1
# E-Commerce, Fashion, Commerce, Collaboration, C...              1
# Finance, Events, Entrepreneur, Startups, Incuba...              1
# Services                                                        1
# Sustainability, E-Commerce                                      1
#
# [789 rows x 1 columns]>

# %%
cc.to_csv("/Users/ansonice/Desktop/rouge_intern/country_entry_counts_12-4-2022.csv")

# %%
United_States = ["USA","United States","US","New York, New York, United States","San Francisco, California","San Francisco","New York, New York, United States","San Francisco, California, United States","New York ","San Francisco, CA, USA","New York","Los Angeles, California, United States",]
India = ["India ","India","Gurgaon Haryana India"]
United_Kingdom = ["United Kingdom","London, England, United Kingdom","London, United Kingdom","UK"]
Singapore = ["Singapore, Central Region, Singapore","Singapore"]

df.loc[df["country"].isin(United_States) ,"after"] = "United States"
df.loc[df["country"].isin(India) ,"after"] = "India"
df.loc[df["country"].isin(United_Kingdom) ,"after"] = "United Kingdom"
df.loc[df["country"].isin(Singapore) ,"after"] = "Singapore"
